# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
% matplotlib inline

# %%
season_data = pd.read_csv('./DataFiles/RegularSeasonDetailedResults.csv')

# %%
season_data.shape #christ.
# Out:
# (76636, 34)

# %%
season_data.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#   ...   LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0 ...      10    16    22   10   22     8   18     9     2   20
# 1 ...      24     9    20   20   25     7   12     8     6   16
# 2 ...      26    14    23   31   22     9   12     2     5   23
# 3 ...      22     8    15   17   20     9   19     4     3   23
# 4 ...      16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 34 columns]

# %%
season_data.dtypes.count
# Out:
# <bound method Series.count of Season      int64
# DayNum      int64
# WTeamID     int64
# WScore      int64
# LTeamID     int64
# LScore      int64
# WLoc       object
# NumOT       int64
# WFGM        int64
# WFGA        int64
# WFGM3       int64
# WFGA3       int64
# WFTM        int64
# WFTA        int64
# WOR         int64
# WDR         int64
# WAst        int64
# WTO         int64
# WStl        int64
# WBlk        int64
# WPF         int64
# LFGM        int64
# LFGA        int64
# LFGM3       int64
# LFGA3       int64
# LFTM        int64
# LFTA        int64
# LOR         int64
# LDR         int64
# LAst        int64
# LTO         int64
# LStl        int64
# LBlk        int64
# LPF         int64
# dtype: object>

# %%
short_data = pd.read_csv('./DataFiles/RegularSeasonCompactResults.csv')

# %%
short_data.shape #christ**2
# Out:
# (150684, 8)

# %%
short_data.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 0    1985      20     1228      81     1328      64    N      0
# 1    1985      25     1106      77     1354      70    H      0
# 2    1985      25     1112      63     1223      56    H      0
# 3    1985      25     1165      70     1432      54    H      0
# 4    1985      25     1192      86     1447      74    H      0

# %%
tourney_results_compact = pd.read_csv('./DataFiles/NCAATourneyCompactResults.csv')
print(tourney_results_compact.dtypes.count())
print(tourney_results_compact.shape)
tourney_results_compact.head()
# Out:
# 8
# (2117, 8)
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 0    1985     136     1116      63     1234      54    N      0
# 1    1985     136     1120      59     1345      58    N      0
# 2    1985     136     1207      68     1250      43    N      0
# 3    1985     136     1229      58     1425      55    N      0
# 4    1985     136     1242      49     1325      38    N      0

# %%
tourney_results_detailed = pd.read_csv('./DataFiles/NCAATourneyDetailedResults.csv')
print(tourney_results_detailed.dtypes.count())
print(tourney_results_detailed.shape)
tourney_results_detailed.head()
# Out:
# 34
# (981, 34)
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     136     1112      80     1436      51    N      0    31    66
# 2    2003     136     1113      84     1272      71    N      0    31    59
# 3    2003     136     1141      79     1166      73    N      0    29    53
# 4    2003     136     1143      76     1301      74    N      1    27    64
#
#   ...   LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0 ...      31    14    31   17   28    16   15     5     0   22
# 1 ...      16     7     7    8   26    12   17    10     3   15
# 2 ...      28    14    21   20   22    11   12     2     5   18
# 3 ...      17    12    17   14   17    20   21     6     6   21
# 4 ...      21    15    20   10   26    16   14     5     8   19
#
# [5 rows x 34 columns]

# %%
tourney_seeds = pd.read_csv('./DataFiles/NCAATourneySeeds.csv')
tourney_seeds.head(10)
# Out:
#    Season Seed  TeamID
# 0    1985  W01    1207
# 1    1985  W02    1210
# 2    1985  W03    1228
# 3    1985  W04    1260
# 4    1985  W05    1374
# 5    1985  W06    1208
# 6    1985  W07    1393
# 7    1985  W08    1396
# 8    1985  W09    1439
# 9    1985  W10    1177
